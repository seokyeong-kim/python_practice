# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from datetime import datetime
help(datetime)
# Out:
# Help on class datetime in module datetime:
#
# class datetime(date)
#  |  datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#  |
#  |  The year, month and day arguments are required. tzinfo may be None, or an
#  |  instance of a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  Method resolution order:
#  |      datetime
#  |      date
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __reduce__(self, /)
#  |      __reduce__() -> (cls, state)
#  |
#  |  __reduce_ex__(...)
#  |      __reduce_ex__(proto) -> (cls, state)
#  |
#  |  __replace__(self, /, **changes)
#  |      The same as replace().
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  astimezone(...)
#  |      tz -> convert to local time in new timezone tz
#  |
#  |  ctime(self, /)
#  |      Return ctime() style string.
#  |
#  |  date(self, /)
#  |      Return date object with same year, month and day.
#  |
#  |  dst(self, /)
#  |      Return self.tzinfo.dst(self).
#  |
#  |  isoformat(...)
#  |      [sep] -> string in ISO 8601 format, YYYY-MM-DDT[HH[:MM[:SS[.mmm[uuu]]]]][+HH:MM].
#  |      sep is used to separate the year from the time, and defaults to 'T'.
#  |      The optional argument timespec specifies the number of additional terms
#  |      of the time to include. Valid options are 'auto', 'hours', 'minutes',
#  |      'seconds', 'milliseconds' and 'microseconds'.
#  |
#  |  replace(self, /, year=unchanged, month=unchanged, day=unchanged,
#  |          hour=unchanged, minute=unchanged, second=unchanged,
#  |          microsecond=unchanged, tzinfo=unchanged, *, fold=unchanged)
#  |      Return datetime with new specified fields.
#  |
#  |  time(self, /)
#  |      Return time object with same time but with tzinfo=None.
#  |
#  |  timestamp(self, /)
#  |      Return POSIX timestamp as float.
#  |
#  |  timetuple(self, /)
#  |      Return time tuple, compatible with time.localtime().
#  |
#  |  timetz(self, /)
#  |      Return time object with same time and tzinfo.
#  |
#  |  tzname(self, /)
#  |      Return self.tzinfo.tzname(self).
#  |
#  |  utcoffset(self, /)
#  |      Return self.tzinfo.utcoffset(self).
#  |
#  |  utctimetuple(self, /)
#  |      Return UTC time tuple, compatible with time.localtime().
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  combine(...)
#  |      date, time -> datetime with same date and time fields
#  |
#  |  fromisoformat(object, /)
#  |      string -> datetime from a string in most ISO 8601 formats
#  |
#  |  fromtimestamp(...)
#  |      timestamp[, tz] -> tz's local time from POSIX timestamp.
#  |
#  |  now(tz=None)
#  |      Returns new datetime object representing current time local to tz.
#  |
#  |        tz
#  |          Timezone object.
#  |
#  |      If no tz is specified, uses local timezone.
#  |
#  |  strptime(...)
#  |      string, format -> new datetime parsed from a string (like time.strptime()).
#  |
#  |  utcfromtimestamp(...)
#  |      Construct a naive UTC datetime from a POSIX timestamp.
#  |
#  |  utcnow()
#  |      Return a new datetime representing UTC day and time.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  fold
#  |
#  |  hour
#  |
#  |  microsecond
#  |
#  |  minute
#  |
#  |  second
#  |
#  |  tzinfo
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  max = datetime.datetime(9999, 12, 31, 23, 59, 59, 999999)
#  |
#  |  min = datetime.datetime(1, 1, 1, 0, 0)
#  |
#  |  resolution = datetime.timedelta(microseconds=1)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from date:
#  |
#  |  __format__(...)
#  |      Formats self with strftime.
#  |
#  |  isocalendar(self, /)
#  |      Return a named tuple containing ISO year, week number, and weekday.
#  |
#  |  isoweekday(self, /)
#  |      Return the day of the week represented by the date.
#  |      Monday == 1 ... Sunday == 7
#  |
#  |  strftime(...)
#  |      format -> strftime() style string.
#  |
#  |  toordinal(self, /)
#  |      Return proleptic Gregorian ordinal.  January 1 of year 1 is day 1.
#  |
#  |  weekday(self, /)
#  |      Return the day of the week represented by the date.
#  |      Monday == 0 ... Sunday == 6
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from date:
#  |
#  |  fromisocalendar(...)
#  |      int, int, int -> Construct a date from the ISO year, week number and weekday.
#  |
#  |      This is the inverse of the date.isocalendar() function
#  |
#  |  fromordinal(...)
#  |      int -> date corresponding to a proleptic Gregorian ordinal.
#  |
#  |  today()
#  |      Current date or datetime:  same as self.__class__.fromtimestamp(time.time()).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from date:
#  |
#  |  day
#  |
#  |  month
#  |
#  |  year

# %%
datetime(2026, 6, 1) #뒤에는 시간값. 0시 0분
# Out:
# datetime.datetime(2026, 6, 1, 0, 0)

# %%
print(datetime(2026,6,2))
# Out:
# 2026-06-02 00:00:00

# %%
from zoneinfo import ZoneInfo

d1 = datetime(2026,6,1,11,25,0,999999,tzinfo=ZoneInfo('Asia/Seoul'))
print(d1)
# Out:
# 2026-06-01 11:25:00.999999+09:00

# %%
import zoneinfo

#모든 타임존
all_timezones = zoneinfo.available_timezones()

#타임존 검색
search = 'Seoul'
result = [tz for tz in all_timezones if search in tz]

print(result)
# Out:
# ['Asia/Seoul']

# %%
import datetime

now = datetime.datetime.now()
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.tzinfo)
# Out:
# 2026
# 6
# 1
# 11
# 50
# None

# %%
my_date=datetime.datetime(2010,1,25,2,10)
weeknames={0:'월',1:'화',2:'수',3:'목',4:'금',5:'토',6:'일'}

print(my_date)
print(my_date.date())
print(my_date.time())
print(weeknames[my_date.weekday()])
# Out:
# 2010-01-25 02:10:00
# 2010-01-25
# 02:10:00
# 월

# %%
weekname= {"Sun":"일", "Mon":"월", "Tue":"화", "Wed":"수", "Thu":"목", "Fri":"금", "Sat":"토"}
now = datetime.datetime.now()

yyyy = now.strftime('%Y') #연도
mm = now.strftime('%m') #달
dd = now.strftime('%d') #일
date =now.strftime('%a') #요일 이름

print(f'{yyyy}년 {mm}월 {dd}일 {weekname[date]}요일')
# Out:
# 2026년 06월 01일 월요일

# %%
now.strftime("%p %I:%M:%S")
# Out:
# 'AM 11:57:12'

# %%
#날짜 시간 간격을 다루기 위한 클래스

from datetime import timedelta
help(timedelta)
# Out:
# Help on class timedelta in module datetime:
#
# class timedelta(builtins.object)
#  |  Difference between two datetime values.
#  |
#  |  timedelta(days=0, seconds=0, microseconds=0, milliseconds=0, minutes=0, hours=0, weeks=0)
#  |
#  |  All arguments are optional and default to 0.
#  |  Arguments may be integers or floats, and may be positive or negative.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __reduce__(self, /)
#  |      __reduce__() -> (cls, state)
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  total_seconds(self, /)
#  |      Total seconds in the duration.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  days
#  |      Number of days.
#  |
#  |  microseconds
#  |      Number of microseconds (>= 0 and less than 1 second).
#  |
#  |  seconds
#  |      Number of seconds (>= 0 and less than 1 day).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  max = datetime.timedelta(days=999999999, seconds=86399, microseconds=9...
#  |
#  |  min = datetime.timedelta(days=-999999999)
#  |
#  |  resolution = datetime.timedelta(microseconds=1)

# %%
delta =timedelta(weeks=1, days=2, hours=3, minutes=30, \
seconds=10, microseconds=333333)
print(delta)
delta
# Out:
# 9 days, 3:30:10.333333
# datetime.timedelta(days=9, seconds=12610, microseconds=333333)

# %%
print(delta) # 279 days, 10:17:48.947387
print(delta.days) # 일 수
print(delta.seconds) # 일 단위를 제외한 초
print(delta.microseconds) # 마이크로 초
print(delta.total_seconds()) # 전체 기간을 초 단위로 반환 ex)9일을 초로 변환
# Out:
# 9 days, 3:30:10.333333
# 9
# 12610
# 333333
# 790210.333333

# %%
now =datetime.datetime.now()
delta =timedelta(days=100)
afterday =now +delta
print(afterday.date())
# Out:
# 2026-09-09

# %%
lastday=datetime.datetime(2026,12,31) 
now =datetime.datetime.now()
delta =lastday-now
print(f'{delta.days}일 남았습니다.')
# Out:
# 212일 남았습니다.

# %%
type(delta)
# Out:
# datetime.timedelta

# %%
#문제) 2026년 1월 1일부터 50일간의 날짜 리스트
from datetime import datetime, timedelta 

first_date = datetime(2026, 1, 1)

date_list = [(first_date + timedelta(days=i)).strftime('%Y %m월 %d일') for i in range(50)]

date_list
# Out:
# ['2026 01월 01일',
#  '2026 01월 02일',
#  '2026 01월 03일',
#  '2026 01월 04일',
#  '2026 01월 05일',
#  '2026 01월 06일',
#  '2026 01월 07일',
#  '2026 01월 08일',
#  '2026 01월 09일',
#  '2026 01월 10일',
#  '2026 01월 11일',
#  '2026 01월 12일',
#  '2026 01월 13일',
#  '2026 01월 14일',
#  '2026 01월 15일',
#  '2026 01월 16일',
#  '2026 01월 17일',
#  '2026 01월 18일',
#  '2026 01월 19일',
#  '2026 01월 20일',
#  '2026 01월 21일',
#  '2026 01월 22일',
#  '2026 01월 23일',
#  '2026 01월 24일',
#  '2026 01월 25일',
#  '2026 01월 26일',
#  '2026 01월 27일',
#  '2026 01월 28일',
#  '2026 01월 29일',
#  '2026 01월 30일',
#  '2026 01월 31일',
#  '2026 02월 01일',
#  '2026 02월 02일',
#  '2026 02월 03일',
#  '2026 02월 04일',
#  '2026 02월 05일',
#  '2026 02월 06일',
#  '2026 02월 07일',
#  '2026 02월 08일',
#  '2026 02월 09일',
#  '2026 02월 10일',
#  '2026 02월 11일',
#  '2026 02월 12일',
#  '2026 02월 13일',
#  '2026 02월 14일',
#  '2026 02월 15일',
#  '2026 02월 16일',
#  '2026 02월 17일',
#  '2026 02월 18일',
#  '2026 02월 19일']

# %%
#코딩 직접 안하고 코덱스에게 만들어달라고 시킬 것이다. 

#문자열로 이루어진 데이터들. 단어들을 토큰으로 쪼개는 토크나이징도 배웠다. 

#넘파이 멧플롯립 씨본 등은 문자형 데이터보다는 숫자형 데이터들 다루는 법이다. 

#판다스 넘파이 등 외울 필요 없다. 데이터 분석하면서 필요하면 검색해서 알아보면 된다. 

#relativedelta 는 delta와는 조금 요법이 다르다.

# %%
from dateutil.relativedelta import relativedelta 
help(relativedelta)
# Out:
# Help on class relativedelta in module dateutil.relativedelta:
#
# class relativedelta(builtins.object)
#  |  relativedelta(
#  |      dt1=None,
#  |      dt2=None,
#  |      years=0,
#  |      months=0,
#  |      days=0,
#  |      leapdays=0,
#  |      weeks=0,
#  |      hours=0,
#  |      minutes=0,
#  |      seconds=0,
#  |      microseconds=0,
#  |      year=None,
#  |      month=None,
#  |      day=None,
#  |      weekday=None,
#  |      yearday=None,
#  |      nlyearday=None,
#  |      hour=None,
#  |      minute=None,
#  |      second=None,
#  |      microsecond=None
#  |  )
#  |
#  |  The relativedelta type is designed to be applied to an existing datetime and
#  |  can replace specific components of that datetime, or represents an interval
#  |  of time.
#  |
#  |  It is based on the specification of the excellent work done by M.-A. Lemburg
#  |  in his
#  |  `mx.DateTime <https://www.egenix.com/products/python/mxBase/mxDateTime/>`_ extension.
#  |  However, notice that this type does *NOT* implement the same algorithm as
#  |  his work. Do *NOT* expect it to behave like mx.DateTime's counterpart.
#  |
#  |  There are two different ways to build a relativedelta instance. The
#  |  first one is passing it two date/datetime classes::
#  |
#  |      relativedelta(datetime1, datetime2)
#  |
#  |  The second one is passing it any number of the following keyword arguments::
#  |
#  |      relativedelta(arg1=x,arg2=y,arg3=z...)
#  |
#  |      year, month, day, hour, minute, second, microsecond:
#  |          Absolute information (argument is singular); adding or subtracting a
#  |          relativedelta with absolute information does not perform an arithmetic
#  |          operation, but rather REPLACES the corresponding value in the
#  |          original datetime with the value(s) in relativedelta.
#  |
#  |      years, months, weeks, days, hours, minutes, seconds, microseconds:
#  |          Relative information, may be negative (argument is plural); adding
#  |          or subtracting a relativedelta with relative information performs
#  |          the corresponding arithmetic operation on the original datetime value
#  |          with the information in the relativedelta.
#  |
#  |      weekday:
#  |          One of the weekday instances (MO, TU, etc) available in the
#  |          relativedelta module. These instances may receive a parameter N,
#  |          specifying the Nth weekday, which could be positive or negative
#  |          (like MO(+1) or MO(-2)). Not specifying it is the same as specifying
#  |          +1. You can also use an integer, where 0=MO. This argument is always
#  |          relative e.g. if the calculated date is already Monday, using MO(1)
#  |          or MO(-1) won't change the day. To effectively make it absolute, use
#  |          it in combination with the day argument (e.g. day=1, MO(1) for first
#  |          Monday of the month).
#  |
#  |      leapdays:
#  |          Will add given days to the date found, if year is a leap
#  |          year, and the date found is post 28 of february.
#  |
#  |      yearday, nlyearday:
#  |          Set the yearday or the non-leap year day (jump leap days).
#  |          These are converted to day/month/leapdays information.
#  |
#  |  There are relative and absolute forms of the keyword
#  |  arguments. The plural is relative, and the singular is
#  |  absolute. For each argument in the order below, the absolute form
#  |  is applied first (by setting each attribute to that value) and
#  |  then the relative form (by adding the value to the attribute).
#  |
#  |  The order of attributes considered when this relativedelta is
#  |  added to a datetime is:
#  |
#  |  1. Year
#  |  2. Month
#  |  3. Day
#  |  4. Hours
#  |  5. Minutes
#  |  6. Seconds
#  |  7. Microseconds
#  |
#  |  Finally, weekday is applied, using the rule described above.
#  |
#  |  For example
#  |
#  |  >>> from datetime import datetime
#  |  >>> from dateutil.relativedelta import relativedelta, MO
#  |  >>> dt = datetime(2018, 4, 9, 13, 37, 0)
#  |  >>> delta = relativedelta(hours=25, day=1, weekday=MO(1))
#  |  >>> dt + delta
#  |  datetime.datetime(2018, 4, 2, 14, 37)
#  |
#  |  First, the day is set to 1 (the first of the month), then 25 hours
#  |  are added, to get to the 2nd day and 14th hour, finally the
#  |  weekday is applied, but since the 2nd is already a Monday there is
#  |  no effect.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self)
#  |
#  |  __add__(self, other)
#  |
#  |  __bool__(self)
#  |
#  |  __div__(self, other)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __init__(
#  |      self,
#  |      dt1=None,
#  |      dt2=None,
#  |      years=0,
#  |      months=0,
#  |      days=0,
#  |      leapdays=0,
#  |      weeks=0,
#  |      hours=0,
#  |      minutes=0,
#  |      seconds=0,
#  |      microseconds=0,
#  |      year=None,
#  |      month=None,
#  |      day=None,
#  |      weekday=None,
#  |      yearday=None,
#  |      nlyearday=None,
#  |      hour=None,
#  |      minute=None,
#  |      second=None,
#  |      microsecond=None
#  |  )
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __mul__(self, other)
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __neg__(self)
#  |
#  |  __nonzero__ = __bool__(self)
#  |
#  |  __radd__(self, other)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __rmul__ = __mul__(self, other)
#  |
#  |  __rsub__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  __truediv__ = __div__(self, other)
#  |
#  |  normalized(self)
#  |      Return a version of this object represented entirely using integer
#  |      values for the relative attributes.
#  |
#  |      >>> relativedelta(days=1.5, hours=2).normalized()
#  |      relativedelta(days=+1, hours=+14)
#  |
#  |      :return:
#  |          Returns a :class:`dateutil.relativedelta.relativedelta` object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  weeks

# %%
relativedelta(year=10, month=1, days=1)
# Out:
# relativedelta(days=+1, year=10, month=1)

# %%
date1 =datetime(2025,1,1,10)
date2 =datetime(2023,1,10,11)
relativedelta(date1, date2)
# Out:
# relativedelta(years=+1, months=+11, days=+21, hours=+23)

# %%
relativedelta(date2,date1)
# Out:
# relativedelta(years=-1, months=-11, days=-21, hours=-23)

# %%
datetime.now() - relativedelta(years=10)
# Out:
# datetime.datetime(2016, 6, 1, 13, 38, 48, 698114)

# %%
import numpy as np
datetimes =['2025-02-01 13:30:01.000001', 
'2026-03-02 14:31:02.000002', 
'2027-04-03 15:32:03.000003']

#연단위 정밀도 
years =np.array(datetimes, dtype='datetime64[Y]')
print(years) 
print(years.dtype)
# Out:
# ['2025' '2026' '2027']
# datetime64[Y]

# %%
#월단위 정밀도
months =np.array(datetimes, dtype= 'datetime64[M]')
print(months) 
print(months.dtype)
# Out:
# ['2025-02' '2026-03' '2027-04']
# datetime64[M]

# %%
#일단위 정밀도 
days =np.array(datetimes, dtype='datetime64[D]')
print(days)
print(days.dtype)
# Out:
# ['2025-02-01' '2026-03-02' '2027-04-03']
# datetime64[D]

# %%
#시간 단위 정밀도 
hours =np.array(datetimes, dtype= 'datetime64[h]')
print(hours)
print(hours.dtype)
# Out:
# ['2025-02-01T13' '2026-03-02T14' '2027-04-03T15']
# datetime64[h]

# %%
#분 단위 정밀도 
minutes =np.array(datetimes, dtype= 'datetime64[m]')
print(minutes) 
print(minutes.dtype)
# Out:
# ['2025-02-01T13:30' '2026-03-02T14:31' '2027-04-03T15:32']
# datetime64[m]

# %%
np.arange('2000', '2026', dtype='datetime64[Y]')
# Out:
# array(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023',
#        '2024', '2025'], dtype='datetime64[Y]')

# %%
np.arange('2000-09', '2003-03', dtype='datetime64[M]')
# Out:
# array(['2000-09', '2000-10', '2000-11', '2000-12', '2001-01', '2001-02',
#        '2001-03', '2001-04', '2001-05', '2001-06', '2001-07', '2001-08',
#        '2001-09', '2001-10', '2001-11', '2001-12', '2002-01', '2002-02',
#        '2002-03', '2002-04', '2002-05', '2002-06', '2002-07', '2002-08',
#        '2002-09', '2002-10', '2002-11', '2002-12', '2003-01', '2003-02'],
#       dtype='datetime64[M]')

# %%
np.arange('2000-02', 15, dtype='datetime64[D]')
# Out:
# array(['2000-02-01', '2000-02-02', '2000-02-03', '2000-02-04',
#        '2000-02-05', '2000-02-06', '2000-02-07', '2000-02-08',
#        '2000-02-09', '2000-02-10', '2000-02-11', '2000-02-12',
#        '2000-02-13', '2000-02-14', '2000-02-15'], dtype='datetime64[D]')

# %%
##pandas의 시계열 타입

datetime_obj = pd.to_datetime('2025')
print(datetime_obj)
print(type(datetime_obj))
# Out:
# 2025-01-01 00:00:00
# <class 'pandas.Timestamp'>

# %%
datetime_obj = pd.to_datetime('2025-03')
print(datetime_obj)
print(type(datetime_obj))
# Out:
# 2025-03-01 00:00:00
# <class 'pandas.Timestamp'>

# %%
datetime_obj = pd.to_datetime('2026-06-01 13')
print(datetime_obj)
print(type(datetime_obj))
# Out:
# 2026-06-01 13:00:00
# <class 'pandas.Timestamp'>

# %%
datetime_obj = pd.to_datetime('2025년 03월 15일 13시 15분 20초', 
format = '%Y년 %m월 %d일 %H시 %M분 %S초')
print(datetime_obj)
print(type(datetime_obj))
# Out:
# 2025-03-15 13:15:20
# <class 'pandas.Timestamp'>

# %%
dates =['2025-01-01', '2025-01-02', '2025-01-03']
df_date=pd.to_datetime(dates)
print(df_date)
print(type(df_date))
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03'], dtype='datetime64[us]', freq=None)
# <class 'pandas.DatetimeIndex'>

# %%
# 2020년부터 연단위 7개의 데이터 생성
pd.date_range('2020', periods=7, freq='YS') #YS = Year Start
# Out:
# DatetimeIndex(['2020-01-01', '2021-01-01', '2022-01-01', '2023-01-01',
#                '2024-01-01', '2025-01-01', '2026-01-01'],
#               dtype='datetime64[us]', freq='YS-JAN')

# %%
#2020년부터 연단위 7개의 데이터 생성
pd.date_range('2020', periods=7, freq='YE')  #YE = Year End
# Out:
# DatetimeIndex(['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31',
#                '2024-12-31', '2025-12-31', '2026-12-31'],
#               dtype='datetime64[us]', freq='YE-DEC')

# %%
df = pd.read_csv('../data/visualization-data/BikeSharingDemand.csv',
                 index_col='datetime', #인덱스로 지정할 칼럼
                 parse_dates=['datetime'])  #datetime자료형으로 변환할 칼럼들
df.head(3)
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 09:00:00        76     0.0000       8           6     14
# 2011-01-01 10:00:00        76    16.9979      12          24     36
# 2011-01-01 11:00:00        81    19.0012      26          30     56
# 2011-01-01 12:00:00        77    19.0012      29          55     84
# 2011-01-02 09:00:00        76    15.0013       1          19     20
# ...                       ...        ...     ...         ...    ...
# 2012-12-18 12:00:00        48    16.9979      49         264    313
# 2012-12-19 09:00:00        75     7.0015       8         309    317
# 2012-12-19 10:00:00        70     7.0015      17         147    164
# 2012-12-19 11:00:00        54    15.0013      31         169    200
# 2012-12-19 12:00:00        54    19.0012      33         203    236
#
# [1821 rows x 11 columns]

# %%
df[['count']].resample(rule="D").mean()  #'D'는 day라는 뜻

#일 평균 - 일당 빌린 횟수 평균
# Out:
#                  count
# datetime
# 2011-01-01   41.041667
# 2011-01-02   34.826087
# 2011-01-03   61.318182
# 2011-01-04   67.913043
# 2011-01-05   69.565217
# ...                ...
# 2012-12-15  210.291667
# 2012-12-16  157.750000
# 2012-12-17  191.041667
# 2012-12-18  231.541667
# 2012-12-19  219.458333
#
# [719 rows x 1 columns]

# %%
df[['count']].resample(rule="MS").mean()

#월 평균 MS = Month Start
# Out:
#                  count
# datetime
# 2011-01-01   54.645012
# 2011-02-01   73.641256
# 2011-03-01   86.849776
# 2011-04-01  111.026374
# 2011-05-01  174.809211
# 2011-06-01  196.877193
# 2011-07-01  203.614035
# 2011-08-01  182.666667
# 2011-09-01  174.622517
# 2011-10-01  174.773626
# 2011-11-01  155.458333
# 2011-12-01  134.173246
# 2012-01-01  124.353201
# 2012-02-01  145.646154
# 2012-03-01  208.276923
# 2012-04-01  257.455947
# 2012-05-01  264.109649
# 2012-06-01  287.186404
# 2012-07-01  267.037281
# 2012-08-01  285.570175
# 2012-09-01  292.598684
# 2012-10-01  280.508772
# 2012-11-01  231.980220
# 2012-12-01  217.054825

# %%
df[['count']].resample(rule="ME").mean()  #월 평균 end(월 마지막날)
# Out:
#                  count
# datetime
# 2011-01-31   54.645012
# 2011-02-28   73.641256
# 2011-03-31   86.849776
# 2011-04-30  111.026374
# 2011-05-31  174.809211
# 2011-06-30  196.877193
# 2011-07-31  203.614035
# 2011-08-31  182.666667
# 2011-09-30  174.622517
# 2011-10-31  174.773626
# 2011-11-30  155.458333
# 2011-12-31  134.173246
# 2012-01-31  124.353201
# 2012-02-29  145.646154
# 2012-03-31  208.276923
# 2012-04-30  257.455947
# 2012-05-31  264.109649
# 2012-06-30  287.186404
# 2012-07-31  267.037281
# 2012-08-31  285.570175
# 2012-09-30  292.598684
# 2012-10-31  280.508772
# 2012-11-30  231.980220
# 2012-12-31  217.054825

# %%
df_daily = df[['count']].resample(rule="D").mean()
df_daily.head()
# Out:
#                 count
# datetime
# 2011-01-01  41.041667
# 2011-01-02  34.826087
# 2011-01-03  61.318182
# 2011-01-04  67.913043
# 2011-01-05  69.565217

# %%
df_daily.plot(title='일 평균 대여량');
# Out:
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\EL022\Documents\5월 4주차\Python 실습\self practice\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df2 = df.copy()
df2.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16
# 2011-01-01 01:00:00        80        0.0       8          32     40
# 2011-01-01 02:00:00        80        0.0       5          27     32
# 2011-01-01 03:00:00        75        0.0       3          10     13
# 2011-01-01 04:00:00        75        0.0       0           1      1

# %%
df2['count-1'] =df2[['count']].shift(1)
df2[['count', 'count-1']].head()
# Out:
#                      count  count-1
# datetime
# 2011-01-01 00:00:00     16      NaN
# 2011-01-01 01:00:00     40     16.0
# 2011-01-01 02:00:00     32     40.0
# 2011-01-01 03:00:00     13     32.0
# 2011-01-01 04:00:00      1     13.0

# %%
df2[['count','count-1']].tail()
# Out:
#                      count  count-1
# datetime
# 2012-12-19 19:00:00    336    569.0
# 2012-12-19 20:00:00    241    336.0
# 2012-12-19 21:00:00    168    241.0
# 2012-12-19 22:00:00    129    168.0
# 2012-12-19 23:00:00     88    129.0

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun gothic')
plt.rc('axes', unicode_minus=False)

# %%
df_daily = df[['count']].resample(rule="D").mean()
df_daily.head()
# Out:
#                 count
# datetime
# 2011-01-01  41.041667
# 2011-01-02  34.826087
# 2011-01-03  61.318182
# 2011-01-04  67.913043
# 2011-01-05  69.565217

# %%
df_daily.plot(title='일 평균 대여량')
pass

# %%
#중간중간 데이터가 빈곳이 있는게 보인다. 그래프상으로 보면. 그건 데이터 누락.

# %%
df_monthly = df[['count']].resample(rule="MS").mean()
df_monthly.head()
# Out:
#                  count
# datetime
# 2011-01-01   54.645012
# 2011-02-01   73.641256
# 2011-03-01   86.849776
# 2011-04-01  111.026374
# 2011-05-01  174.809211

# %%
type(df_monthly.index)
# Out:
# pandas.DatetimeIndex

# %%
print(type(df_monthly.index),df_monthly.index.dtype, df_monthly.index.freq)
#64비트의 데이트타임. monthbegin=monthstart
# Out:
# <class 'pandas.DatetimeIndex'> datetime64[us] <MonthBegin>

# %%
print(copy1.columns)
# Out:
# Index(['count'], dtype='str')

# %%
#다음 코드는 에러남 
df.monthly.plot(kind='bar', title='월 평균 대여량')

xtic = df.monthly.index.strftime('%Y-%m')
plt.xticks(range(len(df_monthly.index)), xtic);

# %%
#Pandas 그래프 그리기 에러를 우회하기 위해 다음처럼 수동으로 그림

copy1 = df_monthly.copy()

labels = copy1.index.strftime('%Y-%m')
fig, ax = plt.subplots(figsize=(10, 4))

ax.bar(range(len(copy1)), copy1['count'])
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels,rotation=90)
ax.set_title('월 평균 대여량')
plt.tight_layout()

# %%
#수동 그리기 방법 2

copy2 = df_monthly.copy()
copy2.index = copy2.index.strftime('%Y-%m')
copy2.plot(kind='bar', title='월 평균 대여량')

plt.tight_layout()

# %%
#shift - 한칸씩 뒤로 이동 
df3 = df.copy()
df3['count-1'] = df3[['count']].shift(1)
df3[['count', 'count-1']].head()
# Out:
#                      count  count-1
# datetime
# 2011-01-01 00:00:00     16      NaN
# 2011-01-01 01:00:00     40     16.0
# 2011-01-01 02:00:00     32     40.0
# 2011-01-01 03:00:00     13     32.0
# 2011-01-01 04:00:00      1     13.0

# %%
df3['diff'] = df3['count'] - df3['count-1']
df3[['count', 'count-1', 'diff']].head()

#이전 데이터와 차이 계산
# Out:
#                      count  count-1  diff
# datetime
# 2011-01-01 00:00:00     16      NaN   NaN
# 2011-01-01 01:00:00     40     16.0  24.0
# 2011-01-01 02:00:00     32     40.0  -8.0
# 2011-01-01 03:00:00     13     32.0 -19.0
# 2011-01-01 04:00:00      1     13.0 -12.0

# %%
df_daily3 = df3[['count']].resample(rule="D").mean()
df_daily3.head()
# Out:
#                 count
# datetime
# 2011-01-01  41.041667
# 2011-01-02  34.826087
# 2011-01-03  61.318182
# 2011-01-04  67.913043
# 2011-01-05  69.565217

# %%
df_daily3['count'].shift(1).head()
# Out:
# datetime
# 2011-01-01          NaN
# 2011-01-02    41.041667
# 2011-01-03    34.826087
# 2011-01-04    61.318182
# 2011-01-05    67.913043
# Freq: D, Name: count, dtype: float64

# %%
df_daily3['count-1'] = df_daily3['count'].shift(1)
df_daily3.head()
# Out:
#                 count    count-1
# datetime
# 2011-01-01  41.041667        NaN
# 2011-01-02  34.826087  41.041667
# 2011-01-03  61.318182  34.826087
# 2011-01-04  67.913043  61.318182
# 2011-01-05  69.565217  67.913043

# %%
df_daily3['count'] - df_daily3['count-1'].head()
# Out:
# datetime
# 2011-01-01          NaN
# 2011-01-02    -6.215580
# 2011-01-03    26.492095
# 2011-01-04     6.594862
# 2011-01-05     1.652174
#                 ...
# 2012-12-15          NaN
# 2012-12-16          NaN
# 2012-12-17          NaN
# 2012-12-18          NaN
# 2012-12-19          NaN
# Freq: D, Length: 719, dtype: float64

# %%
df_daily3['diff'] = df_daily3['count'] - df_daily3['count-1'] 
df_daily3.head()
# Out:
#                 count    count-1       diff
# datetime
# 2011-01-01  41.041667        NaN        NaN
# 2011-01-02  34.826087  41.041667  -6.215580
# 2011-01-03  61.318182  34.826087  26.492095
# 2011-01-04  67.913043  61.318182   6.594862
# 2011-01-05  69.565217  67.913043   1.652174

# %%
df_daily3.loc['2011-10-10' : '2011-10-20', 'diff']  #diff 칼럼만 보겠다는 뜻
# Out:
# datetime
# 2011-10-10   -16.416667
# 2011-10-11   -23.083333
# 2011-10-12   -89.458333
# 2011-10-13    20.708333
# 2011-10-14    30.458333
# 2011-10-15    65.541667
# 2011-10-16    -7.333333
# 2011-10-17   -19.625000
# 2011-10-18     7.416667
# 2011-10-19   -92.442029
# 2011-10-20          NaN
# Freq: D, Name: diff, dtype: float64

# %%
test1 = df_daily3.loc['2011-10-10' : '2011-10-20', 'diff']

test1.plot(kind='bar')
pass

# %%
data = [1,2,3,4,5,6, 7]
idx = pd.date_range('2020-01-01', periods=7, freq='D')
cols = ['col']  #칼럼의 이름 
df4 = pd.DataFrame(data=data, index=idx, columns=cols)
display(df4)
# Out:
#             col
# 2020-01-01    1
# 2020-01-02    2
# 2020-01-03    3
# 2020-01-04    4
# 2020-01-05    5
# 2020-01-06    6
# 2020-01-07    7

# %%
df4.rolling(window=3).mean()
# Out:
#             col
# 2020-01-01  NaN
# 2020-01-02  NaN
# 2020-01-03  2.0
# 2020-01-04  3.0
# 2020-01-05  4.0
# 2020-01-06  5.0
# 2020-01-07  6.0

# %%
df4
# Out:
#             col
# 2020-01-01    1
# 2020-01-02    2
# 2020-01-03    3
# 2020-01-04    4
# 2020-01-05    5
# 2020-01-06    6
# 2020-01-07    7

# %%
df4.rolling(window=3).sum()
# Out:
#              col
# 2020-01-01   NaN
# 2020-01-02   NaN
# 2020-01-03   6.0
# 2020-01-04   9.0
# 2020-01-05  12.0
# 2020-01-06  15.0
# 2020-01-07  18.0

# %%
df4.expanding().mean()  #평균값 구한 것
# Out:
#             col
# 2020-01-01  1.0
# 2020-01-02  1.5
# 2020-01-03  2.0
# 2020-01-04  2.5
# 2020-01-05  3.0
# 2020-01-06  3.5
# 2020-01-07  4.0

# %%
df4.expanding().sum()
# Out:
#              col
# 2020-01-01   1.0
# 2020-01-02   3.0
# 2020-01-03   6.0
# 2020-01-04  10.0
# 2020-01-05  15.0
# 2020-01-06  21.0
# 2020-01-07  28.0
