# %%
#자율적 연습공간

# %%
a = [1,2,3]
b = a

a[1] = 4
print(a)

print(b)

b = a[:]
a[1] = 5
print(a)
print(b)
# Out:
# [1, 4, 3]
# [1, 4, 3]
# [1, 5, 3]
# [1, 4, 3]

# %%
import random
print(random.randint(1,10))
# Out:
# 7

# %%
a = list()
print(a)
# Out:
# []

# %%
a = 'I lost in the forest'
b = a[2]+a[7]+a[14]+a[17]
print(b)
# Out:
# life

# %%
a1 = [1, 2, 3, ['a', 'b', 'c'], 4, 5]
print(a1[3][2])
# Out:
# c

# %%
'abc'*3
a2 = [1,2,3]
a2*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a3 = [1,2,3]
str(a3[1])+'hi'
# Out:
# '2hi'

# %%
a3[1]=4
a3
del a3[2]
a3
# Out:
# [1, 4]

# %%
a3.append(4)
a3
# Out:
# [1, 4, 4]

# %%
a3.append([5,6])
a3
# Out:
# [1, 4, 4, [5, 6]]

# %%
a4 = [4,7,2,9,3]
a4.sort()
a4
# Out:
# [2, 3, 4, 7, 9]

# %%
a5 = ['car','banana','apple']
a5.sort()
a5
# Out:
# ['apple', 'banana', 'car']

# %%
a5.index('apple')
# Out:
# 0

# %%
a5.remove('arrow')
a5
# Out:
# ['apple', 'arrow', 'banana', 'car']

# %%
a5.pop()
a5
# Out:
# ['apple', 'arrow', 'banana']

# %%
a5.pop(1)
a5
# Out:
# ['apple', 'banana']

# %%
a3.count(4)
# Out:
# 2

# %%
a6 = [1,2,3]
a6 += [4,5]
a6
# Out:
# [1, 2, 3, 4, 5]

# %%
#튜플

b = (1,2,3)
b[1]
# Out:
# 2

# %%
b[:1]
# Out:
# (1,)

# %%
b[:2]
# Out:
# (1, 2)

# %%
c = b*3
c
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
len(c)
# Out:
# 9

# %%
a = {1:'a'}
a[2] = 'b'
a
# Out:
# {1: 'a', 2: 'b'}

# %%
a['name'] = 'jana'
a
# Out:
# {1: 'a', 2: 'b', 'name': 'jana'}

# %%
del a[2]
a
# Out:
# {1: 'a'}

# %%
a['hobby'] = 'football'
a
# Out:
# {1: 'a', 'name': 'jana', 'hobby': 'football'}

# %%
a['name']
# Out:
# 'jana'

# %%
a = {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}
a.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %%
for k in a.keys():
    print(k)
# Out:
# name
# phone
# birth

# %%
a.values()
# Out:
# dict_values(['pey', '010-9999-1234', '1118'])

# %%
a.items()
# Out:
# dict_items([('name', 'pey'), ('phone', '010-9999-1234'), ('birth', '1118')])

# %%
a.get('name')
# Out:
# 'pey'

# %%
#a['city'] 를 실행하면 에러를 발생시키지만, a.get('city')를 실행하면 none을 반환한다. 값이 있을지 없을지 모른다면 get함수를 호출해보자.
#none대신 다른 메시지를 뜨게 하고 싶다면 쉼표 찍고 메시지를 입력한다. 
a.get('city', '정보없음')
# Out:
# '정보없음'

# %%
#집합set 자료형 

s1 = set('hello')
s1
# Out:
# {'e', 'h', 'l', 'o'}

# %%
s2 = set([4,2,7])
s2
# Out:
# {2, 4, 7}

# %%
#중복을 허용하지 않으므로 l이 하나밖에 없다. 
#요소의 순서가 없기 때문에 슬라이싱이나 인덱싱 하려면 list나 튜플 자료형으로 변환시킨 다음 한다. 
l1 = list(s1)
l1
# Out:
# ['o', 'h', 'l', 'e']

# %%
l1.sort()
l1
# Out:
# ['e', 'h', 'l', 'o']

# %%
s2.update([3,5])
s2
# Out:
# {2, 3, 4, 5, 7}

# %%
s2.add(8)
s2
# Out:
# {2, 3, 4, 5, 7, 8}

# %%
a7 = [1,2,3,4]
a7.pop()
# Out:
# 4

# %%
while a7:
    print(a7.pop())
# Out:
# 3
# 2
# 1

# %%
test1 = [1,2,3]
test2 = []
print(bool(test1))
print(bool(test2))
# Out:
# True
# False

# %%
a8 = [1,2,3]
b4 = a8
a8.append(4)
b4
# Out:
# [1, 2, 3, 4]

# %%
b5 = a8[:]
b5 is a8
# Out:
# False

# %%
a9 = [1,2,3]
if 4 in a9:
    print('correct')
else:
    print('wrong')
# Out:
# wrong

# %%
for i in a9:
    print('happy')
    if 4 in a9:
        break
    else:
        print('sad')
# Out:
# happy
# sad
# happy
# sad
# happy
# sad

# %%
pocket = ['cash', 'card', 'watch']
if 'cash' or 'card' in pocket:
    print('택시')
else: 
    print('걷기')
# Out:
# 택시

# %%
if 'sunglasses' not in pocket:
    print('눈부셔')
else: 
    print('happy')
# Out:
# 눈부셔

# %%
#pass 에 해당하면 아무 값도 출력되거나 아무 일도 실행되지 않는다. 

if 'watch' in pocket:
    pass
else:
    print('검문')

# %%
grade = 'F'
if grade == 'A':
    print("탁월한 성적입니다.")
elif grade == 'B':
    print("우수한 성적입니다.")
elif grade == 'C':
    print("보통입니다.")
elif grade in ['D','F']:
    print("노력이 필요합니다.")
else:
    print('유효하지 않은 점수입니다')
# Out:
# 노력이 필요합니다.

# %%
treeHit = 0
while treeHit < 10:
    treeHit += 1
    print(f'나무를 {treeHit}번 찍었습니다')
    if treeHit == 10:
        print('나무 넘어갑니다')
# Out:
# 나무를 1번 찍었습니다
# 나무를 2번 찍었습니다
# 나무를 3번 찍었습니다
# 나무를 4번 찍었습니다
# 나무를 5번 찍었습니다
# 나무를 6번 찍었습니다
# 나무를 7번 찍었습니다
# 나무를 8번 찍었습니다
# 나무를 9번 찍었습니다
# 나무를 10번 찍었습니다
# 나무 넘어갑니다

# %%
coffee = 10
money = 300
while money:
    print("돈을 받았으니 커피를 줍니다.")
    coffee = coffee -1
    print(f"남은 커피의 양은 {coffee}개입니다.")
    if coffee == 0:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break
# Out:
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 9개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 8개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 7개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 6개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 5개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 4개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 3개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 2개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 1개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 0개입니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %%
coffee = 10 
while True:
    money = int(input('돈을 넣어주세요: '))
    if money == 300:
        print('커피를 줍니다')
        coffee -= 1
        print(f'남은 커피는 {coffee}개입니다')
    elif money > 300:
        print(f'거스름돈은 {money - 300}입니다')
        coffee -= 1
        print(f'남은 커피는 {coffee}개입니다')
    else:
        print('금액이 부족합니다')
        print(f'남은 커피는 {coffee}개입니다')
    if coffee == 0:
        print('커피콩이 떨어졌습니다')
        break
# Out:
# 거스름돈은 2700입니다
# 남은 커피는 7개입니다
# 금액이 부족합니다
# 남은 커피는 7개입니다
# 금액이 부족합니다
# 남은 커피는 7개입니다
# 커피를 줍니다
# 남은 커피는 6개입니다
# 커피를 줍니다
# 남은 커피는 5개입니다
# 커피를 줍니다
# 남은 커피는 4개입니다
# 커피를 줍니다
# 남은 커피는 3개입니다
# 거스름돈은 300입니다
# 남은 커피는 2개입니다
# 커피를 줍니다
# 남은 커피는 1개입니다
# 커피를 줍니다
# 남은 커피는 0개입니다
# 커피콩이 떨어졌습니다

# %%
i = 2
while i <= 3:
    j = 1
    while j <= 9:
        print(f'{i} x {j} = {i*j}')
        j += 1
    i += 1
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27

# %%
marks = [62, 45, 70, 34, 80]

number = 0 
for mark in marks:
    number += 1
    if mark < 60:
        continue
    print(f'{number}번 학생 합격입니다')
# Out:
# 1번 학생 합격입니다
# 3번 학생 합격입니다
# 5번 학생 합격입니다

# %%
numbers = [1,2,3]
result = []
for num in numbers:
    result.append(num*3)

print(result)
# Out:
# [3, 6, 9]

# %%
a = int(input('첫 번째 정수 입력: '))
b = int(input('두 번째 정수 입력: '))

print('{0} * {1} = {2:,}'.format(a,b,a*b))
# Out:
# 1 * 2 = 2

# %%
a = float(input('첫 번째 값 입력: '))
b = float(input('두 번째 값 입력: '))

print(f'{a:.2f}*{b:.3f} = {a*b:,.2f}')
# Out:
# 3.00*4.000 = 12.00
