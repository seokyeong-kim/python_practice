# %%
##첫번째파일    ipynb는 파이썬 노트북의 확장자다.

# %%
# %pip install ipywidgets
# Out:
# ...
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 914.9/914.9 kB 13.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 21.8 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
# ...

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello Notebook")
# Out:
# Hello Notebook

# %%
for i in range(0, 10):
    print('hello World')
# Out:
# hello World
# hello World
# hello World
# hello World
# hello World
# hello World
# hello World
# hello World
# hello World
# hello World

# %%
import requests


res = requests.get('https://www.google.com')
print(res.status_code)
# Out:
# 200
