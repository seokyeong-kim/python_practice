# %%
# !pip install pandas

# %%
import pandas as pd

# %%
s = pd.Series([100,50,30,10])
s
# Out:
# 0    100
# 1     50
# 2     30
# 3     10
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.index = ['A','B','O','AB']

# %%
s.index
# Out:
# Index(['A', 'B', 'O', 'AB'], dtype='str')

# %%
s
# Out:
# A     100
# B      50
# O      30
# AB     10
# dtype: int64

# %%
family = [['김철수',45,'남',175,'A']
          ,['이영희',43,'여',168,'B']
          ,['김선우',13,'남',160,'A']
          ,['김지우',10,'여',140,'O']
          ,['김현우',7,'남',125,'AB']]

df = pd.DataFrame(family)
df.index = ['아빠','엄마','첫째','둘째','셋째']
df
# Out:
#       0   1  2    3   4
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
#컬럼이 많으면 시스템이 느려진다. 행은 훨씬 많겠지만. b+tree 기반으로 데이터베이스는 검색을 한다.

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns = ['이름','나이','성별','키','혈액형']
df
# Out:
#      이름  나이 성별    키 혈액형
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
d = {
    '이름': ['철수','영희','길동','길순','무개'],
    '나이': [15,16,20,19,23],
    '키': [160.5,158.3,175.0,178.4,185.0]
}
df2 = pd.DataFrame(d)
df2
# Out:
#    이름  나이      키
# 0  철수  15  160.5
# 1  영희  16  158.3
# 2  길동  20  175.0
# 3  길순  19  178.4
# 4  무개  23  185.0

# %%
df3 = df2.copy()
df4 = df3.set_index('이름')
df4
# Out:
#     나이      키
# 이름
# 철수  15  160.5
# 영희  16  158.3
# 길동  20  175.0
# 길순  19  178.4
# 무개  23  185.0

# %%
df3.set_index('이름', inplace=True) #많이들 inplace쓰는 걸 확인할 수 있다. 
df3
# Out:
#     나이      키
# 이름
# 철수  15  160.5
# 영희  16  158.3
# 길동  20  175.0
# 길순  19  178.4
# 무개  23  185.0

# %%
scores = [['1',kate,'f',175,'A']
          ,['2',olivia,'f',168,'B']
          ,['3',sam,'m',160,'A']
          ,['4',sophia,'f',140,'O']
          ,['5',michael,'m',125,'AB']]

# %%
import pandas as pd
df4 = pd.read_csv('example1.csv')
df4
# Out:
#   name  age   city
# 0  홍길동   30  Seoul
# 1  김철수   25     LA
# 2  이영희   28  Tokyo

# %%
df4.shape
# Out:
# (3, 3)

# %%
df4.info
# Out:
# <bound method DataFrame.info of   name  age   city
# 0  홍길동   30  Seoul
# 1  김철수   25     LA
# 2  이영희   28  Tokyo>

# %%
df4.dtypes
# Out:
# name      str
# age     int64
# city      str
# dtype: object

# %%
df4.describe
# Out:
# <bound method NDFrame.describe of   name  age   city
# 0  홍길동   30  Seoul
# 1  김철수   25     LA
# 2  이영희   28  Tokyo>

# %%
df4.nlargest(2, 'age')
# Out:
#   name  age   city
# 0  홍길동   30  Seoul
# 2  이영희   28  Tokyo

# %%
df4['age'].median()
# Out:
# np.float64(28.0)

# %%
df4.value_counts('age')  #각 값의 빈도수를 보여준다
# Out:
# age
# 30    1
# 25    1
# 28    1
# Name: count, dtype: int64

# %%
# !python -m pip install Faker
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.0 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 8.7 MB/s  0:00:00
# ...

# %%
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Christopher Waters'

# %%
fake1 = Faker('ko-KR')
fake1.name()
# Out:
# '서지훈'

# %%
df4.sort_index(ascending=False)  #id 거꾸로 정렬
# Out:
#   name  age   city
# 2  이영희   28  Tokyo
# 1  김철수   25     LA
# 0  홍길동   30  Seoul

# %%
df4.sort_values('age')
# Out:
#   name  age   city
# 1  김철수   25     LA
# 2  이영희   28  Tokyo
# 0  홍길동   30  Seoul

# %%
df4['name']
# Out:
# 0    홍길동
# 1    김철수
# 2    이영희
# Name: name, dtype: str

# %%
type(df4['name'])  #name만 있는 df4의 데이터타입은 시리즈다
# Out:
# pandas.Series

# %%
df4.loc[2] #2번 아이디에 해당하는 모든 값을 가져온다
# Out:
# name      이영희
# age        28
# city    Tokyo
# Name: 2, dtype: object

# %%
df4.loc[2, 'name'] #아이디가 2번인 name값을 가져온다
# Out:
# '이영희'

# %%
df4.iloc[0,2]   #0번 아이디, 3번째 칼럼
# Out:
# 'Seoul'

# %%
df4.loc[2]
# Out:
# name      이영희
# age        28
# city    Tokyo
# Name: 2, dtype: object

# %%
df4.loc[[2,1]]
# Out:
#   name  age   city
# 2  이영희   28  Tokyo
# 1  김철수   25     LA

# %%
df4.loc[0:2]
# Out:
#   name  age   city
# 0  홍길동   30  Seoul
# 1  김철수   25     LA
# 2  이영희   28  Tokyo

# %%
df4.loc[[0,1],['name','age']]
# Out:
#   name  age
# 0  홍길동   30
# 1  김철수   25

# %%
df4.iloc[0:1,[2,1,0]]
# Out:
#     city  age name
# 0  Seoul   30  홍길동

# %%
df4['age']
# Out:
# 0    30
# 1    25
# 2    28
# Name: age, dtype: int64

# %%
df4[['age','name']]
# Out:
#    age name
# 0   30  홍길동
# 1   25  김철수
# 2   28  이영희

# %%
df4.loc[2,['name', 'age']]  #2번의 이름과 나이 가져오기
# Out:
# name    이영희
# age      28
# Name: 2, dtype: object

# %%
df4.loc[[0,1],['name']]  #0번과 1번의 이름을 가져오기
# Out:
#   name
# 0  홍길동
# 1  김철수

# %%
df4.loc[[0,2],['name','age']] #0번과 2번의 이름과 나이를 가져오기
# Out:
#   name  age
# 0  홍길동   30
# 2  이영희   28

# %%
df4.iloc[0:2,[2,1,0]]
# Out:
#     city  age name
# 0  Seoul   30  홍길동
# 1     LA   25  김철수

# %%
scores = [['kate','f',175,'A']
          ,['olivia','f',168,'B']
          ,['sam','m',160,'A']
          ,['sophia','f',140,'O']
          ,['michael','m',125,'AB']]

df5 = pd.DataFrame(scores)
df5.index = [1,2,3,4,5]
df5.columns = ['name','gender','height','bloodtype']
df5
# Out:
#       name gender  height bloodtype
# 1     kate      f     175         A
# 2   olivia      f     168         B
# 3      sam      m     160         A
# 4   sophia      f     140         O
# 5  michael      m     125        AB

# %%
df5.loc[df5['height']==160, ['name','gender','height']]
# Out:
#   name gender  height
# 3  sam      m     160

# %%
scores1 = [['kate',95,100]
          ,['olivia',90,85]
          ,['sam',87,92]
          ,['sophia',100,80]
          ,['michael',85,90]]

df6 = pd.DataFrame(scores1)
df6.index = [1,2,3,4,5]
df6.columns = ['name','국어','영어']
df6
# Out:
#       name   국어   영어
# 1     kate   95  100
# 2   olivia   90   85
# 3      sam   87   92
# 4   sophia  100   80
# 5  michael   85   90

# %%
df6.loc[(df6['국어']==100) & (df6['영어']==80)]
# Out:
#      name   국어  영어
# 4  sophia  100  80

# %%
#열 추가/수정

df6['평균'] = round((df6['국어']+df6['영어'])/2, 1)  #맨 뒤에 ,1 들어가는 건 왜일까?
df6
# Out:
#       name   국어   영어    평균
# 1     kate   95  100  97.5
# 2   olivia   90   85  87.5
# 3      sam   87   92  89.5
# 4   sophia  100   80  90.0
# 5  michael   85   90  87.5

# %%
df6.drop(columns=['평균'])  #컬럼을 삭제한다
# Out:
#       name   국어   영어
# 1     kate   95  100
# 2   olivia   90   85
# 3      sam   87   92
# 4   sophia  100   80
# 5  michael   85   90

# %%
df6.isnull().sum()  #결측치(아예 없는 값)가 몇 개인지 센다
# Out:
# name    0
# 국어      0
# 영어      0
# 평균      0
# dtype: int64

# %%
scores1 = [['kate',None,100]
          ,['olivia',90,85]
          ,['sam',87,92]
          ,['sophia',100,None]
          ,['michael',85,90]]

df7 = pd.DataFrame(scores1)
df7.index = [1,2,3,4,5]
df7.columns = ['name','국어','영어']
df7
# Out:
#       name     국어     영어
# 1     kate    NaN  100.0
# 2   olivia   90.0   85.0
# 3      sam   87.0   92.0
# 4   sophia  100.0    NaN
# 5  michael   85.0   90.0

# %%
df7.ffill()  #결측치를 다음front 행의 값으로 채운다  (아래에서 위로가 순서다)
# Out:
#       name     국어     영어
# 1     kate    NaN  100.0
# 2   olivia   90.0   85.0
# 3      sam   87.0   92.0
# 4   sophia  100.0   92.0
# 5  michael   85.0   90.0

# %%
df7.bfill()  #결측치를 이전before 행의 값으로 채운다
# Out:
#       name     국어     영어
# 1     kate   90.0  100.0
# 2   olivia   90.0   85.0
# 3      sam   87.0   92.0
# 4   sophia  100.0   90.0
# 5  michael   85.0   90.0

# %%
df7.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, 1 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      str
#  1   국어      4 non-null      float64
#  2   영어      4 non-null      float64
# dtypes: float64(2), str(1)
# memory usage: 160.0 bytes

# %%
df7.astype({'영어':'float64'})  #??
# Out:
#       name     국어     영어
# 1     kate    NaN  100.0
# 2   olivia   90.0   85.0
# 3      sam   87.0   92.0
# 4   sophia  100.0    NaN
# 5  michael   85.0   90.0

# %%
#시각화  

# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font',family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

pd.Series([-1,2,3]).plot(title='테스트',figsize=(3,2))  #전체 그래프의 사이즈를 가로 3 세로 2로.
# Out:
# <Axes: title={'center': '테스트'}>

# %%
df7.plot(kind='bar',y='국어',figsize=(4,3), color='red', title='국어점수')
pass  #시각화 이미지에 대한 부가설명을 패스한다는 의미.

# %%
df7.transpose()
# Out:
#           1       2     3       4        5
# name   kate  olivia   sam  sophia  michael
# 국어      NaN    90.0  87.0   100.0     85.0
# 영어    100.0    85.0  92.0     NaN     90.0
